# %% [markdown]
# # Time to use hand rankings to make some ML model to "rank" markets

# %%
# get markets
import pandas as pd 
# these are hand ranked markets 
df_ranked = pd.read_excel("../../Desktop/random_20_markets.xlsx", header=1)

# get markets that are labeled
import sqlite3
df = pd.read_sql("SELECT * FROM markets WHERE id IN (SELECT market_id FROM market_labels)", con=sqlite3.connect('../../indexcast-backend/indexcast.db'))

# get the scores
market_relevance_scores = pd.read_sql("SELECT * FROM market_relevance_scores", con=sqlite3.connect('../../indexcast-backend/indexcast.db'))

# %%
# create a mapping dictionary
score_labels = {
    1: 'volume_total',
    2: 'volume_24h_y',
    3: 'volume_144h',
    4: 'num_traders',
    5: 'num_comments',
    6: 'temporal_relevance',
    7: 'geographical_relevance',
    8: 'index_question_relevance'
}

# map the score_type to its label
market_relevance_scores['score_label'] = market_relevance_scores['score_type_id'].map(score_labels)

# %%
# pivot the scores table
scores_pivot = market_relevance_scores.pivot_table(
    index='market_id',
    columns='score_label',
    values='score_value'
).reset_index()

# merge with markets DataFrame
markets_with_scores = df.merge(
    scores_pivot,
    left_on='id',
    right_on='market_id',
    how='left'
)
markets_with_scores.drop(columns='market_id', inplace=True)

# %%
# select only the relevant columns from markets_with_scores
relevance_cols = ['question', 'geographical_relevance', 'index_question_relevance', 'temporal_relevance']
relevance_data = markets_with_scores[relevance_cols]

# merge with df_ranked using the "question" column
df_ranked = df_ranked.merge(
    relevance_data,
    on='question',
    how='left'
)

# %%
# higher score = more relevant
df_ranked['Rankings'] = df_ranked['Rankings'].max() - df_ranked['Rankings'] + 1

# %%
df_ranked.rename(columns={'volume_24h': 'volume_24h_y'}, inplace=True)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor

features = [
    'temporal_relevance', 'geographical_relevance', 'index_question_relevance'
]

X_train = df_ranked[features]
y_train = df_ranked['Rankings']

model = make_pipeline(
    StandardScaler(),
    MLPRegressor(hidden_layer_sizes=(64, 32), activation='tanh',
             alpha=0.001, learning_rate='adaptive', max_iter=10000,
             random_state=42)
)

model.fit(X_train, y_train)

import joblib
# dump to add to the index cast backend
joblib.dump(model, 'pre-prompting-relevance-filter.joblib')
# Out:
# ['pre-prompting-relevance-filter.joblib']

# %% [markdown]
# # testing

# %%
markets_with_scores['predicted_score'] = model.predict(markets_with_scores[features])
markets_with_scores = markets_with_scores.sort_values(by='predicted_score', ascending=False)
for index, market in markets_with_scores.iterrows():
    print(market["question"] + "\n" + str(market["predicted_score"]))
# Out:
# Will there be 1000 or more human cases of H5N1 in the US by the end of 2025?
# 20.111665516858938
# Will 1000 herds of livestock be infected by H5N1 by the end of 2025 in the USA?
# 20.026651793916486
# H5N1 pandemic occurs before 2026, and the case fatality rate is <5%
# 19.989242612170006
# Will there be more than 1,000 confirmed human cases of H5N1 bird flu in the US by the end of 2025?
# 19.979603442358567
# Will there be a "large-scale bird flu outbreak" (100+ human confirmed H5N1 cases) in the US by the end of 2025?
# 19.952520627190356
# Will the CDC  announce that an epidemic of H5N1 "swine flu" exists anywhere in the United States  during 2025?
# 19.865704958799615
# Will there be 10k or more human cases of H5N1 in the US by the end of 2025?
# 19.583294105703413
# Will the CDC announce that a "bird flu" (H5N1) epidemic  exists anywhere in ther US during 2025?
# 19.461672107092177
# Bird flu added to the WHO's list of emergencies this year?
# 19.42011352168088
# Will there be 100 or more human cases of H5N1 in the US by the end of 2025?
# 19.334063700600574
# If the WHO declare a Public Health Emergency of International Concern for H5N1, will they declare an H5N1 pandemic within a year?
# 19.295708753629874
# How many H5N1 human cases will there be in the USA by end of 2025, according to CDC?
# 19.163634388833554
# How many human cases of H5N1 in the US will there be by the end of 2025?
# 19.042816633017768
# By the end of 2025, will H5N1 Bird Flu have evolved to the point where the CDC declares it a global pandemic for humans?
# 19.036304166303356
# Will at least 100,000 Americans die of bird flu in 2025?
# 18.9909467792185
# Will there be at least 1000 confirmed human cases of H5N1 in the US in 2025?
# 18.871810550320195
# Will the US approve an H5N1 vaccine for any group of people before a pandemic starts?
# 18.74984524722613
# How many human cases of H5N1 in the US will there be by the end of 2025?
# 18.728345686435762
# Will there be at least 1000 confirmed human deaths due to H5N1 in the US in 2025?
# 18.444097360458347
# Will there be at least 10,000 confirmed human cases of H5N1 in the US in 2025?
# 18.331141717333473
# Will the CDC announce that a "bird flu"  (H5N1) epidemic  exists anywhere in the United States  in  2025?
# 18.25617730732554
# Will the WHO declare H5N1 a Public Health Emergency of International Concern in 2025?
# 18.17299461684157
# [Metaculus] Will there be reported human-to-human transmission of highly pathogenic avian influenza H5N1 before 2026?
# 18.122686441765236
# Will there be documented human-to-human transmission of H5N1 (bird flu) before 2026?
# 17.95448321804224
# Will there be a 1m+ bird flu outbreak in humans in the US by the end of 2025?
# 17.918896046042942
# Will there be at least 100,000 confirmed human cases of H5N1 in the US in 2025?
# 17.83830055487768
# "Will the World Health Organization officially declare H5N1 a pandemic before December 31st 2025
# 17.70322073767963
# If H5N1 achieves global human-to-human spread, will it be a dud?
# 17.691159500263975
# Will there be at least 10,000 confirmed human deaths due to H5N1 in the US in 2025?
# 17.64757961413942
# Will more than 10,000 Americans die of H5N1 bird flu by the end of 2025?
# 17.625245128612224
# When will the US H5N1 human case count surpass 100?
# 17.314322452776448
# If H5N1 pandemic occurs by 2026, what will be the confirmed case fatality rate for humans in first 3 months?
# 16.756023898598965
# Will there be an avian flu pandemic before 2026?
# 16.64166491777132
# Will there be more than 1,000 confirmed human cases of H5N1 bird flu in the US by the end of 2025?
# 16.625739207419254
# How many H5N1 bird flu human cases will be confirmed in the US in 2025?
# 16.460454540326953
# What percent of 100M people will die from H5N1 by end of 2025?
# 16.030040536910292
# Will at least 100,000 Americans die of H5N1 by the end of 2025?
# 15.909167173768955
# Will at least 500,000 Americans die of H5N1 by the end of 2024?
# 15.788014621042255
# Will 5000 herds of livestock be infected by H5N1 by the end of June 2025?
# 15.780957626047472
# Will 1000 herds of livestock be infected by H5N1 by the end of 2024?
# 15.775780019499226
# Will at least 100,000 Americans die of H5N1 by the end of 2024?
# 15.720275937914455
# Will there be a large-scale bird flu outbreak in the US in 2024? (100+ cases)
# 15.71822188144417
# During 2023, will multiple media sources report more than 100,000 people in the United States were infected with H5N1?
# 15.710475146888374
# Will 10,000 Americans die of H5N1 before the end of 2024?
# 15.66402213355285
# Will 1000 herds of livestock be infected by H5N1 by the end of March 2025?
# 15.661185318977571
# Will the UK HSA advise that the risk to the general public from bird flu is very low at the end of June 2025?
# 15.543451565739874
# Will 10,000 Americans die of  H5N1 in 2023?
# 15.51325005477593
# Will there be 100 or more human cases of H5N1 in the US by the end of 2024?
# 15.461017151040876
# Will an Avian Influenza Virus in Humans be Declared a PHEIC before 2030? [Metaculus]
# 15.276989399556905
# Will there be 500 or more human cases of H5N1 in the US by the end of 2025?
# 14.654799517441207
# Will the WHO declare an H5N1 pandemic before 2030?
# 14.604809437858203
# H5N1 virus acquires human-to-human easy transmission capability by June 1st, 2027
# 14.584561292712918
# Over 50 million birds will be culled due to US bird flu outbreaks [in 2023]
# 14.57142519770613
# What will be the reciprocal IFR of H5N1, if there is a pandemic?
# 14.568613189090934
# Will the WHO declare a Public Health Emergency of International Concern for H5N1 before 2030?
# 13.978253861081674
# Will anyone die with H5 bird flu in the US in 2025?
# 13.68888307979561
# Will 25 or more states be affected by H5N1 by the end of March 2025?
# 13.533625107432153
# US vaccinates chickens in 2025?
# 13.432357611769104
# Are you currently hedged against an H5N1-induced market crash?
# 13.080958307376653
# Number of H5N1 clinical trials for human treatments registered by April 30, 2025
# 12.997281610859016
# IF RFK is HHS Secretary and H5N1 transmits human-to-human in the US, will he try to curtail vaccine production?
# 12.597152847155234
# Will the CDC or WHO discourage non-essential travel due to H5N1 before July 2025?
# 12.469358148082769
# Will anyone die of H5N1 (bird flu) in the United States in October?
# 12.314756008057076
# Will at least one mink farm worker die from any strain of bird flu in 2023?
# 12.220741927811028
# Will anyone die of H5N1 this month? (February, 2023)
# 12.062037782713782
# Are you currently hedged against an H5N1-induced market crash?
# 11.98781597632268
# Will the FDA issue an EUA or full approval for an mRNA H5N1 vaccine by 2025?
# 11.98243688930832
# Vox Future Perfect 2024: More than 20 million poultry birds will be culled due to bird flu?
# 11.97518324808169
# Will we find conclusive evidence of ongoing cow-to-cow H5N1 transmission this year?
# 11.910293628050182
# Will anyone die of H5N1 this month? (February 2023)
# 11.81555126050393
# Which influenza subtype/lineage will be the first to cause 10 million deaths in a single year?
# 11.745968024192406
# Will the CDC or WHO discourage non-essential travel due to H5N1 before March 2025?
# 11.688275555083846
# Will H5N1 have spread to multiple pig farms in 2024?
# 11.687061333661427
# Will the price of chicken leg quarters increase before the end of 2025?
# 11.591046447369935
# In November, will Manifold think that H5 bird flu was transmitting human-to-human prior to February 12th?
# 11.535236752955283
# Did/will H5N1 come from a laboratory?
# 11.386509410640082
# Supposing H5N1 spreads to humans, which antiviral drug that exists today (Feb 2023) will prove most effective in preventing fatalities?
# 11.35067665281276
# Will a human be infected with H5N1 (bird flu) this winter?
# 11.347595460144698
# Will at least 73 billion chickens be killed for meat in 2025?
# 11.281228574930944
# Will the US federal government declare a public health emergency regarding the H5N1 avian influenza virus in 2024?
# 11.199677967157319
# Supposing H5N1 spreads to humans, which antiviral drug that exists today (Feb 2023) will prove most effective in preventing fatalities?
# 10.56420172269174
# Will an H5N1 mRNA vaccine be developed and enter "late stage" human trials (or wider release) by July 2025?
# 10.498182689375236
# Will there be 100 or more human cases of H5N1 in the US by the end of 2024?
# 10.41610291642626
# Will the CDC announce a bird flu (H5N1) epidemic in the Us during 20025?
# 10.393851566503388
# Will there be "GLOBAL FOOD COLLAPSE! - Shortages Lead To Rations As Globalists Attack Farmers!"?
# 10.324329990427186
# Raw milk sales banned in additional US states due to H5N1 before February 1, 2025
# 9.90686488643358
# Will there be 4 consecutive years in which fewer than X billion chickens are killed before 2080?
# 9.818435333030864
# (H5N1) Which states will have new cases of HPAI in domestic livestock between May 10 and May 31?
# 9.660913345973542
# Will another America contract H5N1 in 2024?
# 9.549752840843945
# What will be the CDC’s official mortality rate of H5N1 on January 1st, 2026?
# 9.36530276503783
# Will there be 3 consecutive years in which fewer than 60 billion chickens are killed before 2050.
# 9.18630512266781
# Will there be reports of H5N1 gain-of-function research conducted in the first half of 2023?
# 9.011646999586846
# Will the price of chicken leg quarters increase?
# 8.738207414745032
# Is H5N1 spreading in non-dairy cattle?
# 8.642629790877715
# First confirmed human-to-human H5N1 transmission by February 1st 2025
# 8.575164121169305
# What will be the total number of H5N1 human cases reported by the CDC in the US at the end of 2024? [0-200]
# 8.300742672973266
# Will the WHO declare an H5N1 pandemic in 2023?
# 8.19648877837074
# Will the WHO declare a Public Health Emergency of International Concern for H5N1 influenza before 2024?
# 8.163243513163847
# Will FDA approve any mRNA vaccine against any strain of influenza before 2028?
# 8.129657062577605
# Will there be any reported human-to-human transmission of H5N1 before 2024?
# 8.122572429852424
# First confirmed human-to-human H5N1 transmission by May 1st 2025
# 7.884069491065105
# Will the US ban feeding chicken shit to cows or pigs in 2025?
# 7.56243771555329
# What will be the total number of H5N1 human cases reported by the CDC in the US by the end of 2024?
# 7.535687308155741
# Will someone die from or with H5N1 Bird Flu in America in 2024?
# 7.286868799960583
# Will H5N1 kill more than 100 million people in 2023?
# 6.993829674725913
# By 2026, will the majority of the USA flu vaccine supply be egg-free?
# 6.933830702503265
# Will chicken be banned in California before 2050?
# 6.770400973527711
# Will chicken be banned in the united states before 2050?
# 6.672636060298277
# Will chicken be banned in Texas before 2050?
# 6.389034535916322
# Will H5N1 kill more than 10 million people in 2023?
# 6.387072272555817
# Will H5N1 (bird flu) kill at least 100 Americans in 2023?
# 6.1011691954522265
# [Metaculus] Will there be any reported human-to-human transmission of H5N1 globally before 2025?
# 5.992130963854122
# Will H5N1 kill more than 10 thousand people in 2023?
# 5.992130963854122
# Will there be a noticeable influenza season in 2022-23?
# 5.7902219591524835
# With the third human case of H5N1 Bird Flu reported in US, how many human cases will be confirmed in 2024?
# 5.754219864021269
# Will the 2022 bird flu outbreak be worse than the 2015 outbreak (more than 50 million birds killed)?
# 5.686389236882322
# Will there be more than 10 laboratory-confirmed human deaths from H5N2 by the end of 2024?
# 5.597744334947703
# Will H5N1 kill more than 100 thousand people in 2023?
# 5.2878269723004765
# Will a pandemic be declared due to H3N2 in 2023?
# 5.1509425167834495
# Will 100 people die of H5N1 in 2023?
# 5.001777121423783
# Will 10,000 people die of H5N1 before the end of 2024?
# 4.906015109895352
# Will H5N1 kill more than 1 million people in 2023?
# 4.780883548078675
# Will 1,000 people die of H5N1 in 2023?
# 4.646452656684517
# Will 10,000 people die of H5N1 in 2023?
# 4.592289427004643
# Will there be at least 10,000 worldwide cases of human infection by HPAI H5N1 before 2025?
# 4.568317272762431
# Will an America die of H5N1 in 2024?
# 4.173137684953887
# Will an mRNA influenza vaccine be available in 2023?
# 4.102608838907811
# Did US per-capita broiler chicken consumption increase by at least 0.5% in 2022? (realityeth secured self-resolving)
# 3.545286727229168
# Will the spread of African Swine Fever cause significant harm to the farming of pigs in China, in 2023?
# 2.9425574771838283
# Will there be there be a resurgence of influenza in Virginia to "High" or "Very High" level during the summer of 2023?
# 2.6600796490043734
# Will Zvi Mowshowitz write at least 3 posts centered on avian flu/H5N1 in 2023?
# 2.03027144106627
# Will H3N2 virus lead to more than one deaths in the US in 2023?
# 1.377690867533968
# Will "H5N1" make the top fifty posts in LessWrong's 2023 Annual Review?
# 0.2769044601339531

# %% [markdown]
# It looks like all relevant markets are scored 13 or higher. To give us a buffer, I propose those scoring greater than 12 should be eligible for rule generation

# %%
import numpy as np 
market_features = np.array([[0.3, 0.42, 0.1]]) 

# Predict the ranking
predicted_ranking = model.predict(market_features)
print(f"Predicted ranking: {predicted_ranking[0]}")
# Out:
# Predicted ranking: 7.401685758375199
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
